# %%
import os
import re
import csv
import time
import math
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %%
# -------------------------------
# STEP 1: READ LINKS FROM EXCEL
# -------------------------------
input_file = "C:/Users/Asus/Pictures/Lenskart/Lenskart_Links.xlsx"
df_links = pd.read_excel(input_file)

possible_cols = [c for c in df_links.columns if "link" in c.lower() or "url" in c.lower()]
if not possible_cols:
    raise ValueError("❌ No column found with 'link' or 'url' in name.")

LINKS = df_links[possible_cols[0]].dropna().tolist()
print(f"✅ Loaded {len(LINKS)} links from Excel.\n")

# -------------------------------
# STEP 2: SETUP SELENIUM DRIVER
# -------------------------------
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument("--disable-notifications")
chrome_options.add_argument("--disable-infobars")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# -------------------------------
# STEP 3: EXTRACT PRODUCTS (FIXED)
# -------------------------------
def extract_products(driver, base_url):
    print(f"\n🌐 Opening page: {base_url}")
    driver.get(base_url)
    time.sleep(6)

    # Try to detect total products (optional)
    total_products = 300  # fallback default
    try:
        soup = BeautifulSoup(driver.page_source, "html.parser")
        total_text = soup.find("div", {"data-cy": "showing-result-desktop"})
        if total_text:
            spans = total_text.find_all("span")
            total_products = int(spans[-2].get_text(strip=True))
            print(f"🔢 Total products found: {total_products}")
    except Exception:
        print("⚠️ Could not detect total products. Using default.")

    # Folder and CSV setup
    category_name = re.sub(r'[\\/*?:"<>|]', "_", base_url.split("/")[-1].replace(".html", ""))
    images_dir = os.path.join("lenskart_images", category_name)
    os.makedirs(images_dir, exist_ok=True)
    output_csv = f"lenskart_{category_name}.csv"

    seen_links = set()
    data = []

    # Progressive scroll + extract loop
    approx_scrolls = math.ceil(total_products / 15) + 10
    print(f"🧮 Estimated scrolls needed: {approx_scrolls}")

    for scroll in range(approx_scrolls):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)
        driver.execute_script("window.scrollBy(0, -550);")
        time.sleep(2)

        soup = BeautifulSoup(driver.page_source, "html.parser")
        product_anchors = soup.find_all("a", {"class": "sc-710ae5be-7 ipZuLh"})

        for a in product_anchors:
            try:
                link = "https://www.lenskart.com" + a.get("href", "")
                if link in seen_links:
                    continue
                seen_links.add(link)

                brand = a.find("p", {"data-cy": "plpProductTitle"})
                brand = brand.get_text(strip=True) if brand else ""

                image = a.find("img")["src"] if a.find("img") else ""

                price = a.find("div", {"data-cy": "plpOfferPrice"})
                price = price.get_text(strip=True) if price else ""

                original_price_tag = a.find("span", {"class": "sc-ddbf73a-0 cWCazb"})
                original_price = original_price_tag.get_text(strip=True) if original_price_tag else ""

                discount_tag = a.find("h5", {"data-cy": "plpTitleTypography"})
                discount = discount_tag.get_text(strip=True) if discount_tag else ""

                rating_tag = a.find("span", {"class": "sc-10fbc79f-1 kSWBHN"})
                rating = rating_tag.get_text(strip=True) if rating_tag else ""

                reviews_tag = a.find("span", {"class": "sc-10fbc79f-1 dFjgXS"})
                reviews = reviews_tag.get_text(strip=True) if reviews_tag else ""

                # Optional image download
                if image:
                    clean_name = re.sub(r'[\\/*?:"<>|]', "_", os.path.basename(image.split("?")[0]))
                    img_name = os.path.join(images_dir, clean_name)
                    if not os.path.exists(img_name):
                        try:
                            img_data = requests.get(image, timeout=10).content
                            with open(img_name, "wb") as f:
                                f.write(img_data)
                        except Exception as e:
                            print(f"⚠️ Error downloading {clean_name}: {e}")

                data.append({
                    "Brand": brand,
                    "Price": price,
                    "Original Price": original_price,
                    "Discount": discount,
                    "Rating": rating,
                    "Reviews": reviews,
                    "Product Link": link,
                    "Image URL": image
                })

            except Exception as e:
                print(f"⚠️ Error parsing product: {e}")

        print(f"⬇️ Scroll {scroll+1}/{approx_scrolls}: {len(seen_links)} products collected...")
        if scroll >= 5 and len(product_anchors) < 10:
            print("🛑 Page seems fully loaded. Stopping early.")
            break

    # Save to CSV
    if data:
        pd.DataFrame(data).to_csv(output_csv, index=False, encoding="utf-8-sig")
        print(f"✅ Saved {len(data)} products to: {output_csv}")
    else:
        print("⚠️ No data found for this page.")

# -------------------------------
# STEP 4: MAIN EXECUTION
# -------------------------------
for link in LINKS:
    try:
        extract_products(driver, link)
    except Exception as e:
        print(f"❌ Error while processing {link}: {e}")
        continue

driver.quit()
print("\n🎯 All pages scraped successfully!")
# Out:
# ✅ Loaded 4 links from Excel.
#
#
# 🌐 Opening page: https://www.lenskart.com/eyeglasses/collections/all-computer-glasses.html
# 🔢 Total products found: 408
# 🧮 Estimated scrolls needed: 38
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-blue-full-rim-rectangle-lenskart-blu-lb-e13737-c2_lenskart-blu-lb-e13737-c2-eyeglasses_lenskart-blu-lb-e13737-c2-eyeglasses_eyeglasses_g_101023_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-blue-full-rim-rectangle-lenskart-blu-lb-e13737-c2_lenskart-blu-lb-e13737-c2-eyeglasses_lenskart-blu-lb-e13737-c2-eyeglasses_eyeglasses_g_101023_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-light-blue-transparent-full-rim-round-lenskart-blu-lb-e14061-c1_lenskart-blu-lb-e14061-c1-eyeglasses_lenskart-blu-lb-e14061-c1-eyeglasses_eyeglasses_g_9196_325_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-light-blue-transparent-full-rim-round-lenskart-blu-lb-e14061-c1_lenskart-blu-lb-e14061-c1-eyeglasses_lenskart-blu-lb-e14061-c1-eyeglasses_eyeglasses_g_9196_325_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-grey-transparent-grey-full-rim-round-lenskart-blu-lb-e14061-c3_lenskart-blu-lb-e14061-c3-eyeglasses_lenskart-blu-lb-e14061-c3-eyeglasses_eyeglasses_g_0732_125_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-grey-transparent-grey-full-rim-round-lenskart-blu-lb-e14061-c3_lenskart-blu-lb-e14061-c3-eyeglasses_lenskart-blu-lb-e14061-c3-eyeglasses_eyeglasses_g_0732_125_02_2022.jpg'
# ⬇️ Scroll 1/38: 30 products collected...
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-matte-green-matte-green-full-rim-round-lenskart-blu-lb-e13736-c4_enskart-blu-lb-e13736-full-rim-round-c4-eyeglasses_enskart-blu-lb-e13736-full-rim-round-c4-eyeglasses_eyeglasses_g_098623_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-matte-green-matte-green-full-rim-round-lenskart-blu-lb-e13736-c4_enskart-blu-lb-e13736-full-rim-round-c4-eyeglasses_enskart-blu-lb-e13736-full-rim-round-c4-eyeglasses_eyeglasses_g_098623_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-pink-transparent-pink-full-rim-round-lenskart-blu-lb-e14061-c2_lenskart-blu-lb-e14062-c2-eyeglasses_lenskart-blu-lb-e14062-c2-eyeglasses_eyeglasses_g_0739_125_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-pink-transparent-pink-full-rim-round-lenskart-blu-lb-e14061-c2_lenskart-blu-lb-e14062-c2-eyeglasses_lenskart-blu-lb-e14062-c2-eyeglasses_eyeglasses_g_0739_125_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-silver-tortoise-full-rim-round-lenskart-blu-lb-e14131-c1_lenskart-blu-lb-e14131-c1-c1-eyeglasses_lenskart-blu-lb-e14131-c1-c1-eyeglasses_g_988325_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-silver-tortoise-full-rim-round-lenskart-blu-lb-e14131-c1_lenskart-blu-lb-e14131-c1-c1-eyeglasses_lenskart-blu-lb-e14131-c1-c1-eyeglasses_g_988325_02_2022.jpg'
# ⬇️ Scroll 2/38: 45 products collected...
# ⬇️ Scroll 3/38: 45 products collected...
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-gold-black-full-rim-round-lenskart-blu-lb-e14131-c2_lenskart-blu-lb-e14131-c2-c2-eyeglasses_lenskart-blu-lb-e14131-c2-c2-eyeglasses_g_8358_125_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-gold-black-full-rim-round-lenskart-blu-lb-e14131-c2_lenskart-blu-lb-e14131-c2-c2-eyeglasses_lenskart-blu-lb-e14131-c2-c2-eyeglasses_g_8358_125_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14067-c4_lenskart-blu-lb-e14067-c4-eyeglasses_lenskart-blu-lb-e14067-c4-eyeglasses_g_130025_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14067-c4_lenskart-blu-lb-e14067-c4-eyeglasses_lenskart-blu-lb-e14067-c4-eyeglasses_g_130025_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14241-c2_lenskart-blu-lb-e14241-c2-eyeglasses_lenskart-blu-lb-e14241-c2-eyeglasses_g_430525_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14241-c2_lenskart-blu-lb-e14241-c2-eyeglasses_lenskart-blu-lb-e14241-c2-eyeglasses_g_430525_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14242-c1_lenskart-blu-lb-e14242-c1-eyeglasses_lenskart-blu-lb-e14242-c1-eyeglasses_g_431225_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e14242-c1_lenskart-blu-lb-e14242-c1-eyeglasses_lenskart-blu-lb-e14242-c1-eyeglasses_g_431225_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-brown-transparent-full-rim-rectangle-lenskart-blu-lb-e14242-c3_lenskart-blu-lb-e14242-c3-eyeglasses_lenskart-blu-lb-e14242-c3-eyeglasses_g_481825_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-brown-transparent-full-rim-rectangle-lenskart-blu-lb-e14242-c3_lenskart-blu-lb-e14242-c3-eyeglasses_lenskart-blu-lb-e14242-c3-eyeglasses_g_481825_02_2022.jpg'
# ⬇️ Scroll 4/38: 60 products collected...
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-matte-black-red-full-rim-rectangle-lenskart-blu-lb-e14255-c2_lenskart-blu-lb-e14255-c2-eyeglasses_lenskart-blu-lb-e14255-c2-eyeglasses_g_9922_125_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-matte-black-red-full-rim-rectangle-lenskart-blu-lb-e14255-c2_lenskart-blu-lb-e14255-c2-eyeglasses_lenskart-blu-lb-e14255-c2-eyeglasses_g_9922_125_02_2022.jpg'
# ⬇️ Scroll 5/38: 75 products collected...
# ⬇️ Scroll 6/38: 90 products collected...
# ⬇️ Scroll 7/38: 105 products collected...
# ⬇️ Scroll 8/38: 120 products collected...
# ⬇️ Scroll 9/38: 135 products collected...
# ⬇️ Scroll 10/38: 150 products collected...
# ⬇️ Scroll 11/38: 165 products collected...
# ⬇️ Scroll 12/38: 180 products collected...
# ⬇️ Scroll 13/38: 195 products collected...
# ⬇️ Scroll 14/38: 210 products collected...
# ⬇️ Scroll 15/38: 225 products collected...
# ⬇️ Scroll 16/38: 240 products collected...
# ⬇️ Scroll 17/38: 255 products collected...
# ⬇️ Scroll 18/38: 270 products collected...
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-matte-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e13738-c2_lenskart-blu-lb-e13738-c2-eyeglasses_lenskart-blu-lb-e13738-c2-eyeglasses_yeglasses_eyeglasses_g_0426_223_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-matte-grey-transparent-full-rim-rectangle-lenskart-blu-lb-e13738-c2_lenskart-blu-lb-e13738-c2-eyeglasses_lenskart-blu-lb-e13738-c2-eyeglasses_yeglasses_eyeglasses_g_0426_223_02_2022.jpg'
# ⬇️ Scroll 19/38: 285 products collected...
# ⬇️ Scroll 20/38: 300 products collected...
# ⬇️ Scroll 21/38: 315 products collected...
# ⬇️ Scroll 22/38: 330 products collected...
# ⬇️ Scroll 23/38: 345 products collected...
# ⬇️ Scroll 24/38: 360 products collected...
# ⬇️ Scroll 25/38: 360 products collected...
# ⬇️ Scroll 26/38: 390 products collected...
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-gold-black-full-rim-round-lenskart-blu-lb-e14131-c2_lenskart-blu-lb-e14131-c2-c2-eyeglasses_lenskart-blu-lb-e14131-c2-c2-eyeglasses_g_8358_125_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-gold-black-full-rim-round-lenskart-blu-lb-e14131-c2_lenskart-blu-lb-e14131-c2-c2-eyeglasses_lenskart-blu-lb-e14131-c2-c2-eyeglasses_g_8358_125_02_2022.jpg'
# ⚠️ Error downloading blue-block-phone-&-computer-glasses_-silver-tortoise-full-rim-round-lenskart-blu-lb-e14131-c1_lenskart-blu-lb-e14131-c1-c1-eyeglasses_lenskart-blu-lb-e14131-c1-c1-eyeglasses_g_988325_02_2022.jpg: [Errno 2] No such file or directory: 'lenskart_images\\all-computer-glasses\\blue-block-phone-&-computer-glasses_-silver-tortoise-full-rim-round-lenskart-blu-lb-e14131-c1_lenskart-blu-lb-e14131-c1-c1-eyeglasses_lenskart-blu-lb-e14131-c1-c1-eyeglasses_g_988325_02_2022.jpg'
# ⬇️ Scroll 27/38: 405 products collected...
# ⬇️ Scroll 28/38: 408 products collected...
# ⬇️ Scroll 29/38: 408 products collected...
# ⬇️ Scroll 30/38: 408 products collected...
# ⬇️ Scroll 31/38: 408 products collected...
# ⬇️ Scroll 32/38: 408 products collected...
# ⬇️ Scroll 33/38: 408 products collected...
# ⬇️ Scroll 34/38: 408 products collected...
# ⬇️ Scroll 35/38: 408 products collected...
# ⬇️ Scroll 36/38: 408 products collected...
# ⬇️ Scroll 37/38: 408 products collected...
# ⬇️ Scroll 38/38: 408 products collected...
# ✅ Saved 408 products to: lenskart_all-computer-glasses.csv
#
# 🌐 Opening page: https://www.lenskart.com/sunglasses.html
# 🔢 Total products found: 1061
# 🧮 Estimated scrolls needed: 81
# ⬇️ Scroll 1/81: 15 products collected...
# ⬇️ Scroll 2/81: 15 products collected...
# ⬇️ Scroll 3/81: 15 products collected...
# ⚠️ Error downloading silver-black-sky-blue-mirror-full-rim-aviator-shape-vincent-chase-polarized-the-metal-edit-vc-s11075-c7-polarized-sunglasses_vincent-chase-polarized-vc-s11075-c7-sunglasses_sunglasses_g_4936_1_1_5july23.jpg: [Errno 2] No such file or directory: 'lenskart_images\\sunglasses\\silver-black-sky-blue-mirror-full-rim-aviator-shape-vincent-chase-polarized-the-metal-edit-vc-s11075-c7-polarized-sunglasses_vincent-chase-polarized-vc-s11075-c7-sunglasses_sunglasses_g_4936_1_1_5july23.jpg'
# ⬇️ Scroll 4/81: 30 products collected...
# ⬇️ Scroll 5/81: 30 products collected...
# ⬇️ Scroll 6/81: 30 products collected...
# ⬇️ Scroll 7/81: 30 products collected...
# ❌ Error while processing https://www.lenskart.com/sunglasses.html: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=141.0.7390.123); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0xfbfe43+66515]
# 	GetHandleVerifier [0x0xfbfe84+66580]
# 	(No symbol) [0x0xdadc48]
# 	(No symbol) [0x0xd9ce80]
# 	(No symbol) [0x0xdbb81b]
# 	(No symbol) [0x0xe21c25]
# 	(No symbol) [0x0xe3c4d9]
# 	(No symbol) [0x0xe1afc6]
# 	(No symbol) [0x0xdec2ca]
# 	(No symbol) [0x0xded154]
# 	GetHandleVerifier [0x0x1217353+2521315]
# 	GetHandleVerifier [0x0x12122d3+2500707]
# 	GetHandleVerifier [0x0xfe7c94+229924]
# 	GetHandleVerifier [0x0xfd81f8+165768]
# 	GetHandleVerifier [0x0xfdecad+193085]
# 	GetHandleVerifier [0x0xfc8158+100072]
# 	GetHandleVerifier [0x0xfc82f0+100480]
# 	GetHandleVerifier [0x0xfb25aa+11066]
# 	BaseThreadInitThunk [0x0x754e5d49+25]
# 	RtlInitializeExceptionChain [0x0x772cd6db+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x772cd661+561]
#
#
# 🌐 Opening page: https://www.lenskart.com/eyeglasses/promotions/all-kids-eyeglasses.html
# ❌ Error while processing https://www.lenskart.com/eyeglasses/promotions/all-kids-eyeglasses.html: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0xfbfe43+66515]
# 	GetHandleVerifier [0x0xfbfe84+66580]
# 	(No symbol) [0x0xdada6b]
# 	(No symbol) [0x0xdeb5ab]
# 	(No symbol) [0x0xe1b086]
# 	(No symbol) [0x0xe1667c]
# 	(No symbol) [0x0xe15bf3]
# 	(No symbol) [0x0xd7e72d]
# 	(No symbol) [0x0xd7ecae]
# 	(No symbol) [0x0xd7f14d]
# 	GetHandleVerifier [0x0x1217353+2521315]
# 	GetHandleVerifier [0x0x12122d3+2500707]
# 	GetHandleVerifier [0x0xfe7c94+229924]
# 	GetHandleVerifier [0x0xfd81f8+165768]
# 	GetHandleVerifier [0x0xfdecad+193085]
# 	(No symbol) [0x0xd7e3e3]
# 	(No symbol) [0x0xd7db60]
# 	GetHandleVerifier [0x0x135c20f+3852191]
# 	BaseThreadInitThunk [0x0x754e5d49+25]
# 	RtlInitializeExceptionChain [0x0x772cd6db+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x772cd661+561]
#
#
# 🌐 Opening page: https://www.lenskart.com/eyeglasses.html
# ❌ Error while processing https://www.lenskart.com/eyeglasses.html: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0xfbfe43+66515]
# 	GetHandleVerifier [0x0xfbfe84+66580]
# 	(No symbol) [0x0xdada6b]
# 	(No symbol) [0x0xdeb5ab]
# 	(No symbol) [0x0xe1b086]
# 	(No symbol) [0x0xe1667c]
# 	(No symbol) [0x0xe15bf3]
# 	(No symbol) [0x0xd7e72d]
# 	(No symbol) [0x0xd7ecae]
# 	(No symbol) [0x0xd7f14d]
# 	GetHandleVerifier [0x0x1217353+2521315]
# 	GetHandleVerifier [0x0x12122d3+2500707]
# 	GetHandleVerifier [0x0xfe7c94+229924]
# 	GetHandleVerifier [0x0xfd81f8+165768]
# 	GetHandleVerifier [0x0xfdecad+193085]
# 	(No symbol) [0x0xd7e3e3]
# 	(No symbol) [0x0xd7db60]
# 	GetHandleVerifier [0x0x135c20f+3852191]
# 	BaseThreadInitThunk [0x0x754e5d49+25]
# 	RtlInitializeExceptionChain [0x0x772cd6db+107]
# 	RtlGetAppContainerNamedObjectPath [0x0x772cd661+561]
#
#
# 🎯 All pages scraped successfully!
